# %% [markdown]
# # Quality Assessment of Food Knowledge Graph
#
# The goal is to craft rules to identify at least 10 different data quality issues across multiple dimensions including **semantic accuracy**, **consistency**, **completeness**, **conciseness**.

# %% [markdown]
# ## Create the SHACL shapes
#
# SHACL shapes define constraints on the structure and content of RDF data. These shapes will be used to validate the quality of the knowledge graph in `food_kg.ttl`. The goal is to identify different data quality issues that fall under semantic accuracy, consistency, completeness and conciseness.

# %%
# Import required libraries
import rdflib
from rdflib import Graph, Literal, Namespace, BNode
from rdflib.collection import Collection
from pyshacl import validate, shapes_graph

# Define namespaces
OWL = Namespace('http://www.w3.org/2002/07/owl#')
RDF = Namespace('http://www.w3.org/1999/02/22-rdf-syntax-ns#')
RDFS = Namespace('http://www.w3.org/2000/01/rdf-schema#')
XSD = Namespace('http://www.w3.org/2001/XMLSchema#')
SCHEMA = Namespace('https://schema.org/')
DBO = Namespace('http://dbpedia.org/ontology/')
DBR = Namespace('http://dbpedia.org/resource/')
SH = Namespace('http://www.w3.org/ns/shacl#')
KGS = Namespace('http://kg-course.io/food-nutrition/')

# Parse the ontology graph
ontology_g = Graph().parse('food_kg_ontology.ttl', format='ttl' )

# Create a new graph for SHACL shapes
shapes_g = Graph()
shapes_g.bind('owl', OWL)
shapes_g.bind('rdf', RDF)
shapes_g.bind('rdfs', RDFS)
shapes_g.bind('xsd', XSD)
shapes_g.bind('schema', SCHEMA)
shapes_g.bind('dbo', DBO)
shapes_g.bind('dbr', DBR)
shapes_g.bind('sh', SH)
shapes_g.bind('kgs', KGS)

def get_name_from_uri(uri) -> str:
    return uri.split('#')[-1] if '#' in uri else uri.split('/')[-1]

# Procedure to create SHACL shapes for classes from an ontology graph
def create_class_shape(ontology_graph: Graph, shapes_graph: Graph):
    for cls in ontology_graph.subjects(RDF.type, OWL.Class):
        shape_name = get_name_from_uri(cls) + "Shape"
        shapes_graph.add((KGS[shape_name], RDF.type, SH.NodeShape))
        shapes_graph.add((KGS[shape_name], SH.targetClass, cls))

# Procedure to create SHACL properties from an ontology graph
def create_property_shape(ontology_graph: Graph, shapes_graph: Graph):
    for prop in ontology_graph.subjects(RDF.type, [OWL.ObjectProperty, OWL.DatatypeProperty]):
        # Get the domain and range of the property
        domain = ontology_graph.value(prop, RDFS.domain)
        range = ontology_graph.value(prop, RDFS.range)
        # Get the names of the domain and range to creaet the shape name
        node_name = get_name_from_uri(domain) + "Shape"
        shape_name = node_name + f"_{get_name_from_uri(prop)}"
        # Add the property shape to the graph
        shapes_graph.add((KGS[node_name], SH.property, KGS[shape_name]))
        shapes_graph.add((KGS[shape_name], RDF.type, SH.PropertyShape))
        shapes_graph.add((KGS[shape_name], SH.path, prop))
        if get_name_from_uri(range) == 'string':
            shapes_graph.add((KGS[shape_name], SH.datatype, RDF.langString))
            list_node = BNode()
            Collection(shapes_graph, list_node, [Literal('en')])
            shapes_graph.add((KGS[shape_name], SH.languageIn, list_node))
        else:
            shapes_graph.add((KGS[shape_name], SH.datatype, range))
        shapes_graph.add((KGS[shape_name], SH.minCount, Literal(1)))
    # print(shapes_graph.serialize(format='turtle'))

create_class_shape(ontology_g, shapes_g)
create_property_shape(ontology_g, shapes_g)
shapes_g.serialize(destination='food_kg_shapes.ttl', format='ttl')
print(shapes_g.serialize(format='turtle'))
# Out:
# @prefix dbo: <http://dbpedia.org/ontology/> .
# @prefix kgs: <http://kg-course.io/food-nutrition/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix schema: <https://schema.org/> .
# @prefix sh: <http://www.w3.org/ns/shacl#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# kgs:NutritionInformationShape a sh:NodeShape ;
#     sh:property kgs:NutritionInformationShape_calories,
#         kgs:NutritionInformationShape_carbohydrateContent,
#         kgs:NutritionInformationShape_cholesterolContent,
#         kgs:NutritionInformationShape_fatContent,
#         kgs:NutritionInformationShape_fiberContent,
#         kgs:NutritionInformationShape_proteinContent,
#         kgs:NutritionInformationShape_saturatedFatContent,
#         kgs:NutritionInformationShape_sodiumContent,
#         kgs:NutritionInformationShape_sugarContent ;
#     sh:targetClass schema:NutritionInformation .
#
# kgs:NutritionShape a sh:NodeShape ;
#     sh:targetClass dbo:Nutrition .
#
# kgs:RecipeShape a sh:NodeShape ;
#     sh:property kgs:RecipeShape_cookTime,
#         kgs:RecipeShape_name,
#         kgs:RecipeShape_nutrition,
#         kgs:RecipeShape_prepTime,
#         kgs:RecipeShape_recipeCategory,
#         kgs:RecipeShape_recipeIngredient,
#         kgs:RecipeShape_recipeInstructions ;
#     sh:targetClass schema:Recipe .
#
# kgs:NutritionInformationShape_calories a sh:PropertyShape ;
#     sh:datatype xsd:double ;
#     sh:minCount 1 ;
#     sh:path schema:calories .
#
# kgs:NutritionInformationShape_carbohydrateContent a sh:PropertyShape ;
#     sh:datatype xsd:double ;
#     sh:minCount 1 ;
#     sh:path schema:carbohydrateContent .
#
# kgs:NutritionInformationShape_cholesterolContent a sh:PropertyShape ;
#     sh:datatype xsd:double ;
#     sh:minCount 1 ;
#     sh:path schema:cholesterolContent .
#
# kgs:NutritionInformationShape_fatContent a sh:PropertyShape ;
#     sh:datatype xsd:double ;
#     sh:minCount 1 ;
#     sh:path schema:fatContent .
#
# kgs:NutritionInformationShape_fiberContent a sh:PropertyShape ;
#     sh:datatype xsd:double ;
#     sh:minCount 1 ;
#     sh:path schema:fiberContent .
#
# kgs:NutritionInformationShape_proteinContent a sh:PropertyShape ;
#     sh:datatype xsd:double ;
#     sh:minCount 1 ;
#     sh:path schema:proteinContent .
#
# kgs:NutritionInformationShape_saturatedFatContent a sh:PropertyShape ;
#     sh:datatype xsd:double ;
#     sh:minCount 1 ;
#     sh:path schema:saturatedFatContent .
#
# kgs:NutritionInformationShape_sodiumContent a sh:PropertyShape ;
#     sh:datatype xsd:double ;
#     sh:minCount 1 ;
#     sh:path schema:sodiumContent .
#
# kgs:NutritionInformationShape_sugarContent a sh:PropertyShape ;
#     sh:datatype xsd:double ;
#     sh:minCount 1 ;
#     sh:path schema:sugarContent .
#
# kgs:RecipeShape_cookTime a sh:PropertyShape ;
#     sh:datatype xsd:duration ;
#     sh:minCount 1 ;
#     sh:path schema:cookTime .
#
# kgs:RecipeShape_name a sh:PropertyShape ;
#     sh:datatype rdf:langString ;
#     sh:languageIn ( "en" ) ;
#     sh:minCount 1 ;
#     sh:path schema:name .
#
# kgs:RecipeShape_nutrition a sh:PropertyShape ;
#     sh:datatype schema:NutritionInformation ;
#     sh:minCount 1 ;
#     sh:path schema:nutrition .
#
# kgs:RecipeShape_prepTime a sh:PropertyShape ;
#     sh:datatype xsd:duration ;
#     sh:minCount 1 ;
#     sh:path schema:prepTime .
#
# kgs:RecipeShape_recipeCategory a sh:PropertyShape ;
#     sh:datatype rdf:langString ;
#     sh:languageIn ( "en" ) ;
#     sh:minCount 1 ;
#     sh:path schema:recipeCategory .
#
# kgs:RecipeShape_recipeIngredient a sh:PropertyShape ;
#     sh:datatype rdf:langString ;
#     sh:languageIn ( "en" ) ;
#     sh:minCount 1 ;
#     sh:path schema:recipeIngredient .
#
# kgs:RecipeShape_recipeInstructions a sh:PropertyShape ;
#     sh:datatype rdf:langString ;
#     sh:languageIn ( "en" ) ;
#     sh:minCount 1 ;
#     sh:path schema:recipeInstructions .

# %% [markdown]
# ## Validate the knowledge graph using the created SHACL shapes
# Now that we have created the SHACL shapes based on the ontology, we can use these shapes to validate the `food_kg.ttl` knowledge graph. The validation will check for any violations of the constraints defined in the SHACL shapes, such as missing properties, incorrect data types, or structural issues.

# %%
conforms, v_graph, v_text = validate(data_graph='food_kg.ttl', shacl_graph='food_kg_shapes.ttl', inference='rdfs', debug=False, serialize_report_graph=True)
# Out:
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#duration, Converter=<function parse_xsd_duration at 0x10c7639c0>
# Traceback (most recent call last):
#   File "/Users/alexanderleonidas/Maastricht University/AI Masters/KEN4256 Building and Mining Knowledge Graphs/fluffy_octo_spoon/venv/lib/python3.13/site-packages/rdflib/term.py", line 2262, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/Users/alexanderleonidas/Maastricht University/AI Masters/KEN4256 Building and Mining Knowledge Graphs/fluffy_octo_spoon/venv/lib/python3.13/site-packages/rdflib/xsd_datetime.py", line 427, in parse_xsd_duration
#     raise ValueError("Unable to parse duration string " + dur_string)
# ValueError: Unable to parse duration string nan
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#duration, Converter=<function parse_xsd_duration at 0x10c7639c0>
# Traceback (most recent call last):
#   File "/Users/alexanderleonidas/Maastricht University/AI Masters/KEN4256 Building and Mining Knowledge Graphs/fluffy_octo_spoon/venv/lib/python3.13/site-packages/rdflib/term.py", line 2262, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/Users/alexanderleonidas/Maastricht University/AI Masters/KEN4256 Building and Mining Knowledge Graphs/fluffy_octo_spoon/venv/lib/python3.13/site-packages/rdflib/xsd_datetime.py", line 427, in parse_xsd_duration
#     raise ValueError("Unable to parse duration string " + dur_string)
# ValueError: Unable to parse duration string nan
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#duration, Converter=<function parse_xsd_duration at 0x10c7639c0>
# Traceback (most recent call last):
#   File "/Users/alexanderleonidas/Maastricht University/AI Masters/KEN4256 Building and Mining Knowledge Graphs/fluffy_octo_spoon/venv/lib/python3.13/site-packages/rdflib/term.py", line 2262, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/Users/alexanderleonidas/Maastricht University/AI Masters/KEN4256 Building and Mining Knowledge Graphs/fluffy_octo_spoon/venv/lib/python3.13/site-packages/rdflib/xsd_datetime.py", line 427, in parse_xsd_duration
#     raise ValueError("Unable to parse duration string " + dur_string)
# ValueError: Unable to parse duration string nan
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#duration, Converter=<function parse_xsd_duration at 0x10c7639c0>
# Traceback (most recent call last):
#   File "/Users/alexanderleonidas/Maastricht University/AI Masters/KEN4256 Building and Mining Knowledge Graphs/fluffy_octo_spoon/venv/lib/python3.13/site-packages/rdflib/term.py", line 2262, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/Users/alexanderleonidas/Maastricht University/AI Masters/KEN4256 Building and Mining Knowledge Graphs/fluffy_octo_spoon/venv/lib/python3.13/site-packages/rdflib/xsd_datetime.py", line 427, in parse_xsd_duration
#     raise ValueError("Unable to parse duration string " + dur_string)
# ValueError: Unable to parse duration string nan
# Failed to convert Literal lexical form to value. Datatype=http://www.w3.org/2001/XMLSchema#duration, Converter=<function parse_xsd_duration at 0x10c7639c0>
# Traceback (most recent call last):
#   File "/Users/alexanderleonidas/Maastricht University/AI Masters/KEN4256 Building and Mining Knowledge Graphs/fluffy_octo_spoon/venv/lib/python3.13/site-packages/rdflib/term.py", line 2262, in _castLexicalToPython
#     return conv_func(lexical)  # type: ignore[arg-type]
#   File "/Users/alexanderleonidas/Maastricht University/AI Masters/KEN4256 Building and Mining Knowledge Graphs/fluffy_octo_spoon/venv/lib/python3.13/site-packages/rdflib/xsd_datetime.py", line 427, in parse_xsd_duration
#     raise ValueError("Unable to parse duration string " + dur_string)
# ValueError: Unable to parse duration string nan

# %%
print(conforms)
# Out:
# False

# %%
print(v_graph)
# Out:
# b'@prefix kgs: <http://kg-course.io/food-nutrition/> .\n@prefix schema: <https://schema.org/> .\n@prefix sh: <http://www.w3.org/ns/shacl#> .\n@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .\n\n[] a sh:ValidationReport ;\n    sh:conforms false ;\n    sh:result [ a sh:ValidationResult ;\n            sh:focusNode <http://kg-course/food-nutrition/recipe/57879> ;\n            sh:resultMessage "Value is not Literal with datatype xsd:string" ;\n            sh:resultPath schema:recipeInstructions ;\n            sh:resultSeverity sh:Violation ;\n            sh:sourceConstraintComponent sh:DatatypeConstraintComponent ;\n            sh:sourceShape kgs:RecipeShape_recipeInstructions ;\n            sh:value "Cream butter and slowly beat in sugar."@en ],\n        [ a sh:ValidationResult ;\n            sh:focusNode <http://kg-course/food-nutrition/recipe/57856> ;\n            sh:resultMessage "Value is not Literal with datatype xsd:string" ;\n            sh:resultPath schema:recipeInstructions ;\n            sh:resultSeverity sh:Violation ;\n            sh:sourceConstraintComponent sh:DatatypeConstraintComponent ;\n            sh:sourceShape kgs:RecipeShape_recipeInstructions ;\n            sh:value "Place second layer (cut side down] over filling."@en ],\n        [ a sh:ValidationResult ;\n            sh:focusNode <http://kg-course/food-nutrition/recipe/57856> ;\n            sh:resultMessage "Value is not Literal with datatype xsd:string" ;\n            sh:resultPath schema:recipeInstructions ;\n            sh:resultSeverity sh:Violation ;\n            sh:sourceConstraintComponent sh:DatatypeConstraintComponent ;\n            sh:sourceShape kgs:RecipeShape_recipeInstructions ;\n            sh:value "To make filling: Stir all filling ingredients except vanilla (milk-egg yolks] in a 2-quart saucepan over medium-low heat."@en ],\n        [ a sh:ValidationResult ;\n            sh:focusNode <http://kg-course/food-nutrition/recipe/74837> ;\n            sh:resultMessage "Value is not Literal with datatype xsd:string" ;\n            sh:resultPath schema:recipeInstructions ;\n            sh:resultSeverity sh:Violation ;\n            sh:sourceConstraintComponent sh:DatatypeConstraintComponent ;\n            sh:sourceShape kgs:RecipeShape_recipeInstructions ;\n            sh:value "Frosting: Bring the sugar, cornstarch, chocolate, salt and water to a boil; cook, stirring, 3-5 minutes or until thickened enough to coat a spoon thickly; remove from heat, add butter and vanilla and stir until combined."@en ],\n        [ a sh:ValidationResult ;\n            sh:focusNode <http://kg-course/food-nutrition/recipe/235499> ;\n            sh:resultMessage "Value is not Literal with datatype xsd:string" ;\n            sh:resultPath schema:recipeIngredient ;\n            sh:resultSeverity sh:Violation ;\n            sh:sourceConstraintComponent sh:DatatypeConstraintComponent ;\n            sh:sourceShape kgs:RecipeShape_recipeIngredient ;\n            sh:value "1 1/2 bittersweet chocolate"@en ],\n        [ a sh:ValidationResult ;\n            sh:focusNode <http://kg-course/food-nutrition/recipe/235499> ;\n            sh:resultMessage "Value is not Literal with datatype xsd:string" ;\n            sh:resultPath schema:recipeInstructions ;\n            sh:resultSeverity sh:Violation ;\n            sh:sourceConstraintComponent sh:DatatypeConstraintComponent ;\n            sh:sourceShape kgs:RecipeShape_recipeInstructions ;\n            sh:value "On low speed, beat in flour in 3 additions alternating with milk in 2 additions, just until blended."@en ],\n        [ a sh:ValidationResult ;\n            sh:focusNode <http://kg-course/food-nutrition/recipe/237567> ;\n            sh:resultMessage "Value is not Literal with datatype xsd:string" ;\n            sh:resultPath schema:recipeIngredient ;\n            sh:resultSeverity sh:Violation ;\n            sh:sourceConstraintComponent sh:DatatypeConstraintComponent ;\n            sh:sourceShape kgs:RecipeShape_recipeIngredi ...

# %%
print(v_text)
# Out:
# Validation Report
# Conforms: False
# Results (104):
# Constraint Violation in DatatypeConstraintComponent (http://www.w3.org/ns/shacl#DatatypeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:NutritionInformationShape_calories
# 	Focus Node: <http://kg-course/food-nutrition/recipe/49/nutrition>
# 	Value Node: Literal("6.277e+02")
# 	Result Path: schema:calories
# 	Message: Value is not Literal with datatype xsd:double
# Constraint Violation in DatatypeConstraintComponent (http://www.w3.org/ns/shacl#DatatypeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:NutritionInformationShape_fiberContent
# 	Focus Node: <http://kg-course/food-nutrition/recipe/41/nutrition>
# 	Value Node: Literal("-0.2", datatype=xsd:decimal)
# 	Result Path: schema:fiberContent
# 	Message: Value is not Literal with datatype xsd:double
# Constraint Violation in DatatypeConstraintComponent (http://www.w3.org/ns/shacl#DatatypeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:NutritionInformationShape_fiberContent
# 	Focus Node: <http://kg-course/food-nutrition/recipe/42/nutrition>
# 	Value Node: Literal("0.2")
# 	Result Path: schema:fiberContent
# 	Message: Value is not Literal with datatype xsd:double
# Constraint Violation in DatatypeConstraintComponent (http://www.w3.org/ns/shacl#DatatypeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_cookTime
# 	Focus Node: <http://kg-course/food-nutrition/recipe/162371>
# 	Value Node: Literal("nan", datatype=xsd:duration)
# 	Result Path: schema:cookTime
# 	Message: Value is not Literal with datatype xsd:duration
# Constraint Violation in DatatypeConstraintComponent (http://www.w3.org/ns/shacl#DatatypeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_cookTime
# 	Focus Node: <http://kg-course/food-nutrition/recipe/280584>
# 	Value Node: Literal("nan", datatype=xsd:duration)
# 	Result Path: schema:cookTime
# 	Message: Value is not Literal with datatype xsd:duration
# Constraint Violation in DatatypeConstraintComponent (http://www.w3.org/ns/shacl#DatatypeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_cookTime
# 	Focus Node: <http://kg-course/food-nutrition/recipe/337283>
# 	Value Node: Literal("nan", datatype=xsd:duration)
# 	Result Path: schema:cookTime
# 	Message: Value is not Literal with datatype xsd:duration
# Constraint Violation in DatatypeConstraintComponent (http://www.w3.org/ns/shacl#DatatypeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_cookTime
# 	Focus Node: <http://kg-course/food-nutrition/recipe/46>
# 	Value Node: Literal("nan", datatype=xsd:duration)
# 	Result Path: schema:cookTime
# 	Message: Value is not Literal with datatype xsd:duration
# Constraint Violation in DatatypeConstraintComponent (http://www.w3.org/ns/shacl#DatatypeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_cookTime
# 	Focus Node: <http://kg-course/food-nutrition/recipe/48>
# 	Value Node: Literal("nan", datatype=xsd:duration)
# 	Result Path: schema:cookTime
# 	Message: Value is not Literal with datatype xsd:duration
# Constraint Violation in DatatypeConstraintComponent (http://www.w3.org/ns/shacl#DatatypeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/38>
# 	Value Node: <http://kg-course/food-nutrition/recipe/38/nutrition>
# 	Result Path: schema:nutrition
# 	Message: Value is not Literal with datatype schema:NutritionInformation
# Constraint Violation in DatatypeConstraintComponent (http://www.w3.org/ns/shacl#DatatypeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/39>
# 	Value Node: <http://kg-course/food-nutrition/recipe/39/nutrition>
# 	Result Path: schema:nutrition
# 	Message: Value is not Literal with datatype schema:NutritionInformation
# Constraint Violation in DatatypeConstraintComponent (http://www.w3.org/ns/shacl#DatatypeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/40>
# 	Value Node: <http://kg-course/food-nutrition/recipe/40/nutrition>
# 	Result Path: schema:nutrition
# 	Message: Value is not Literal with datatype schema:NutritionInformation
# Constraint Violation in DatatypeConstraintComponent (http://www.w3.org/ns/shacl#DatatypeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/41>
# 	Value Node: <http://kg-course/food-nutrition/recipe/41/nutrition>
# 	Result Path: schema:nutrition
# 	Message: Value is not Literal with datatype schema:NutritionInformation
# Constraint Violation in DatatypeConstraintComponent (http://www.w3.org/ns/shacl#DatatypeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/42>
# 	Value Node: <http://kg-course/food-nutrition/recipe/42/nutrition>
# 	Result Path: schema:nutrition
# 	Message: Value is not Literal with datatype schema:NutritionInformation
# Constraint Violation in DatatypeConstraintComponent (http://www.w3.org/ns/shacl#DatatypeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/43>
# 	Value Node: <http://kg-course/food-nutrition/recipe/43/nutrition>
# 	Result Path: schema:nutrition
# 	Message: Value is not Literal with datatype schema:NutritionInformation
# Constraint Violation in DatatypeConstraintComponent (http://www.w3.org/ns/shacl#DatatypeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/44>
# 	Value Node: <http://kg-course/food-nutrition/recipe/44/nutrition>
# 	Result Path: schema:nutrition
# 	Message: Value is not Literal with datatype schema:NutritionInformation
# Constraint Violation in DatatypeConstraintComponent (http://www.w3.org/ns/shacl#DatatypeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/45>
# 	Value Node: <http://kg-course/food-nutrition/recipe/45/nutrition>
# 	Result Path: schema:nutrition
# 	Message: Value is not Literal with datatype schema:NutritionInformation
# Constraint Violation in DatatypeConstraintComponent (http://www.w3.org/ns/shacl#DatatypeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/46>
# 	Value Node: <http://kg-course/food-nutrition/recipe/46/nutrition>
# 	Result Path: schema:nutrition
# 	Message: Value is not Literal with datatype schema:NutritionInformation
# Constraint Violation in DatatypeConstraintComponent (http://www.w3.org/ns/shacl#DatatypeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/47>
# 	Value Node: <http://kg-course/food-nutrition/recipe/47/nutrition>
# 	Result Path: schema:nutrition
# 	Message: Value is not Literal with datatype schema:NutritionInformation
# Constraint Violation in DatatypeConstraintComponent (http://www.w3.org/ns/shacl#DatatypeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/48>
# 	Value Node: Literal("cholesterol")
# 	Result Path: schema:nutrition
# 	Message: Value is not Literal with datatype schema:NutritionInformation
# Constraint Violation in DatatypeConstraintComponent (http://www.w3.org/ns/shacl#DatatypeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/49>
# 	Value Node: <http://example.org/nonexistent/Nutrition>
# 	Result Path: schema:nutrition
# 	Message: Value is not Literal with datatype schema:NutritionInformation
# Constraint Violation in DatatypeConstraintComponent (http://www.w3.org/ns/shacl#DatatypeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/88095/>
# 	Value Node: <http://kg-course/food-nutrition/recipe/43/nutrition>
# 	Result Path: schema:nutrition
# 	Message: Value is not Literal with datatype schema:NutritionInformation
# Constraint Violation in DatatypeConstraintComponent (http://www.w3.org/ns/shacl#DatatypeConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_prepTime
# 	Focus Node: <http://kg-course/food-nutrition/recipe/74837>
# 	Value Node: Literal("45", datatype=xsd:int)
# 	Result Path: schema:prepTime
# 	Message: Value is not Literal with datatype xsd:duration
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:NutritionInformationShape_calories
# 	Focus Node: <http://example.org/nonexistent/Nutrition>
# 	Result Path: schema:calories
# 	Message: Less than 1 values on <http://example.org/nonexistent/Nutrition>->schema:calories
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:NutritionInformationShape_calories
# 	Focus Node: Literal("cholesterol")
# 	Result Path: schema:calories
# 	Message: Less than 1 values on Literal("cholesterol")->schema:calories
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:NutritionInformationShape_carbohydrateContent
# 	Focus Node: <http://example.org/nonexistent/Nutrition>
# 	Result Path: schema:carbohydrateContent
# 	Message: Less than 1 values on <http://example.org/nonexistent/Nutrition>->schema:carbohydrateContent
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:NutritionInformationShape_carbohydrateContent
# 	Focus Node: Literal("cholesterol")
# 	Result Path: schema:carbohydrateContent
# 	Message: Less than 1 values on Literal("cholesterol")->schema:carbohydrateContent
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:NutritionInformationShape_cholesterolContent
# 	Focus Node: <http://example.org/nonexistent/Nutrition>
# 	Result Path: schema:cholesterolContent
# 	Message: Less than 1 values on <http://example.org/nonexistent/Nutrition>->schema:cholesterolContent
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:NutritionInformationShape_cholesterolContent
# 	Focus Node: Literal("cholesterol")
# 	Result Path: schema:cholesterolContent
# 	Message: Less than 1 values on Literal("cholesterol")->schema:cholesterolContent
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:NutritionInformationShape_fatContent
# 	Focus Node: <http://example.org/nonexistent/Nutrition>
# 	Result Path: schema:fatContent
# 	Message: Less than 1 values on <http://example.org/nonexistent/Nutrition>->schema:fatContent
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:NutritionInformationShape_fatContent
# 	Focus Node: Literal("cholesterol")
# 	Result Path: schema:fatContent
# 	Message: Less than 1 values on Literal("cholesterol")->schema:fatContent
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:NutritionInformationShape_fiberContent
# 	Focus Node: <http://example.org/nonexistent/Nutrition>
# 	Result Path: schema:fiberContent
# 	Message: Less than 1 values on <http://example.org/nonexistent/Nutrition>->schema:fiberContent
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:NutritionInformationShape_fiberContent
# 	Focus Node: Literal("cholesterol")
# 	Result Path: schema:fiberContent
# 	Message: Less than 1 values on Literal("cholesterol")->schema:fiberContent
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:NutritionInformationShape_proteinContent
# 	Focus Node: <http://example.org/nonexistent/Nutrition>
# 	Result Path: schema:proteinContent
# 	Message: Less than 1 values on <http://example.org/nonexistent/Nutrition>->schema:proteinContent
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:NutritionInformationShape_proteinContent
# 	Focus Node: Literal("cholesterol")
# 	Result Path: schema:proteinContent
# 	Message: Less than 1 values on Literal("cholesterol")->schema:proteinContent
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:NutritionInformationShape_saturatedFatContent
# 	Focus Node: <http://example.org/nonexistent/Nutrition>
# 	Result Path: schema:saturatedFatContent
# 	Message: Less than 1 values on <http://example.org/nonexistent/Nutrition>->schema:saturatedFatContent
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:NutritionInformationShape_saturatedFatContent
# 	Focus Node: Literal("cholesterol")
# 	Result Path: schema:saturatedFatContent
# 	Message: Less than 1 values on Literal("cholesterol")->schema:saturatedFatContent
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:NutritionInformationShape_sodiumContent
# 	Focus Node: <http://example.org/nonexistent/Nutrition>
# 	Result Path: schema:sodiumContent
# 	Message: Less than 1 values on <http://example.org/nonexistent/Nutrition>->schema:sodiumContent
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:NutritionInformationShape_sodiumContent
# 	Focus Node: Literal("cholesterol")
# 	Result Path: schema:sodiumContent
# 	Message: Less than 1 values on Literal("cholesterol")->schema:sodiumContent
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:NutritionInformationShape_sugarContent
# 	Focus Node: <http://example.org/nonexistent/Nutrition>
# 	Result Path: schema:sugarContent
# 	Message: Less than 1 values on <http://example.org/nonexistent/Nutrition>->schema:sugarContent
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:NutritionInformationShape_sugarContent
# 	Focus Node: Literal("cholesterol")
# 	Result Path: schema:sugarContent
# 	Message: Less than 1 values on Literal("cholesterol")->schema:sugarContent
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/100573>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/100573>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/121241>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/121241>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/142426>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/142426>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/148683>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/148683>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/162371>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/162371>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/204921>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/204921>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/213018>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/213018>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/235499>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/235499>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/237567>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/237567>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/241266>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/241266>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/241886>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/241886>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/242430>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/242430>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/244649>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/244649>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/245931>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/245931>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/262155>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/262155>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/280584>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/280584>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/295900>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/295900>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/305119>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/305119>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/314970>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/314970>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/318443>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/318443>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/321461>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/321461>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/323316>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/323316>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/323652>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/323652>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/323867>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/323867>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/336136>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/336136>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/337283>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/337283>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/406237>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/406237>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/416077>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/416077>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/434130>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/434130>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/44395>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/44395>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/45881>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/45881>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/484928>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/484928>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/48678>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/48678>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/510419>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/510419>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/520961>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/520961>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/536304>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/536304>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/55724>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/55724>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/57856>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/57856>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/57879>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/57879>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/58643>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/58643>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/74837>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/74837>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/88096>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/88096>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_nutrition
# 	Focus Node: <http://kg-course/food-nutrition/recipe/98664>
# 	Result Path: schema:nutrition
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/98664>->schema:nutrition
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_recipeIngredient
# 	Focus Node: <http://kg-course/food-nutrition/recipe/162371>
# 	Result Path: schema:recipeIngredient
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/162371>->schema:recipeIngredient
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_recipeIngredient
# 	Focus Node: <http://kg-course/food-nutrition/recipe/204921>
# 	Result Path: schema:recipeIngredient
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/204921>->schema:recipeIngredient
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_recipeIngredient
# 	Focus Node: <http://kg-course/food-nutrition/recipe/241886>
# 	Result Path: schema:recipeIngredient
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/241886>->schema:recipeIngredient
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_recipeIngredient
# 	Focus Node: <http://kg-course/food-nutrition/recipe/242430>
# 	Result Path: schema:recipeIngredient
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/242430>->schema:recipeIngredient
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_recipeIngredient
# 	Focus Node: <http://kg-course/food-nutrition/recipe/318443>
# 	Result Path: schema:recipeIngredient
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/318443>->schema:recipeIngredient
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_recipeIngredient
# 	Focus Node: <http://kg-course/food-nutrition/recipe/321461>
# 	Result Path: schema:recipeIngredient
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/321461>->schema:recipeIngredient
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_recipeIngredient
# 	Focus Node: <http://kg-course/food-nutrition/recipe/337283>
# 	Result Path: schema:recipeIngredient
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/337283>->schema:recipeIngredient
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_recipeIngredient
# 	Focus Node: <http://kg-course/food-nutrition/recipe/39>
# 	Result Path: schema:recipeIngredient
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/39>->schema:recipeIngredient
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_recipeIngredient
# 	Focus Node: <http://kg-course/food-nutrition/recipe/40>
# 	Result Path: schema:recipeIngredient
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/40>->schema:recipeIngredient
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_recipeIngredient
# 	Focus Node: <http://kg-course/food-nutrition/recipe/43>
# 	Result Path: schema:recipeIngredient
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/43>->schema:recipeIngredient
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_recipeIngredient
# 	Focus Node: <http://kg-course/food-nutrition/recipe/44395>
# 	Result Path: schema:recipeIngredient
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/44395>->schema:recipeIngredient
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_recipeIngredient
# 	Focus Node: <http://kg-course/food-nutrition/recipe/44>
# 	Result Path: schema:recipeIngredient
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/44>->schema:recipeIngredient
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_recipeIngredient
# 	Focus Node: <http://kg-course/food-nutrition/recipe/45881>
# 	Result Path: schema:recipeIngredient
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/45881>->schema:recipeIngredient
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_recipeIngredient
# 	Focus Node: <http://kg-course/food-nutrition/recipe/484928>
# 	Result Path: schema:recipeIngredient
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/484928>->schema:recipeIngredient
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_recipeIngredient
# 	Focus Node: <http://kg-course/food-nutrition/recipe/48678>
# 	Result Path: schema:recipeIngredient
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/48678>->schema:recipeIngredient
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_recipeIngredient
# 	Focus Node: <http://kg-course/food-nutrition/recipe/510419>
# 	Result Path: schema:recipeIngredient
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/510419>->schema:recipeIngredient
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_recipeIngredient
# 	Focus Node: <http://kg-course/food-nutrition/recipe/55724>
# 	Result Path: schema:recipeIngredient
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/55724>->schema:recipeIngredient
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_recipeIngredient
# 	Focus Node: <http://kg-course/food-nutrition/recipe/57879>
# 	Result Path: schema:recipeIngredient
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/57879>->schema:recipeIngredient
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_recipeIngredient
# 	Focus Node: <http://kg-course/food-nutrition/recipe/88095/>
# 	Result Path: schema:recipeIngredient
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/88095/>->schema:recipeIngredient
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_recipeIngredient
# 	Focus Node: <http://kg-course/food-nutrition/recipe/98664>
# 	Result Path: schema:recipeIngredient
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/98664>->schema:recipeIngredient
# Constraint Violation in MinCountConstraintComponent (http://www.w3.org/ns/shacl#MinCountConstraintComponent):
# 	Severity: sh:Violation
# 	Source Shape: kgs:RecipeShape_recipeInstructions
# 	Focus Node: <http://kg-course/food-nutrition/recipe/46>
# 	Result Path: schema:recipeInstructions
# 	Message: Less than 1 values on <http://kg-course/food-nutrition/recipe/46>->schema:recipeInstructions
